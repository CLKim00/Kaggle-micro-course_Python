# %%
import pandas as pd
reviews = pd.read_csv("winemag-data-130k-v2.csv", index_col=0)
pd.set_option('max_rows', 5)

# %% [markdown]
# # Native accessors

# %%
reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 36167     Italy  Here's a straightforward and fruity Nero d'Avo...
# 36168    Greece  This rounded white starts with aromas of lemon...
#
#         designation  points  price           province region_1 region_2  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1          Avidagos      87   15.0              Douro      NaN      NaN
# ...             ...     ...    ...                ...      ...      ...
# 36167           NaN      88   18.0  Sicily & Sardinia  Sicilia      NaN
# 36168     Dry White      88   15.0        Peloponnese      NaN      NaN
#
#            taster_name taster_twitter_handle  \
# 0        Kerin O’Keefe          @kerinokeefe
# 1           Roger Voss            @vossroger
# ...                ...                   ...
# 36167    Kerin O’Keefe          @kerinokeefe
# 36168  Susan Kostrzewa         @suskostrzewa
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                              ...             ...
# 36167           Morgante 2012 Nero d'Avola (Sicilia)    Nero d'Avola
# 36168  My Big Fat Greek Wine 2012 Dry White Moschofi             NaN
#
#                     winery
# 0                  Nicosia
# 1      Quinta dos Avidagos
# ...                    ...
# 36167             Morgante
# 36168                  NaN
#
# [36169 rows x 13 columns]

# %%
# Access the property of an object by accessing it as an attribute
reviews.country
# Out:
# 0           Italy
# 1        Portugal
#            ...
# 36167       Italy
# 36168      Greece
# Name: country, Length: 36169, dtype: object

# %%
# Access its values using the indexing [] operator
reviews['country']
# Out:
# 0           Italy
# 1        Portugal
#            ...
# 36167       Italy
# 36168      Greece
# Name: country, Length: 36169, dtype: object

# %%
# indexing operator [] does have the advantage that it can handle column names with reserved characters in them
# (e.g. if we had a 'country providence' column, reviews.country providence wouldn't work)

# %%
# To drill down to a single specific value, use the indexing operator [] once more:
reviews['country'][0]
# Out:
# 'Italy'

# %% [markdown]
# # Indexing in pandas
# Index-based selection

# %%
# Select the first row
reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
# Get a column with iloc
reviews.iloc[:, 0]
# Out:
# 0           Italy
# 1        Portugal
#            ...
# 36167       Italy
# 36168      Greece
# Name: country, Length: 36169, dtype: object

# %%
# the : operator means "everything".
# When combined with other selectors, however, it can be used to indicate a range of values.
reviews.iloc[:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[1:3, 0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
reviews.iloc[[0, 1, 2], 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
# last five elements of the dataset
reviews.iloc[-5:]
# Out:
#        country                                        description  \
# 36164  Austria  Distant woodsmoke, ripe blueberry and notions ...
# 36165       US  Here is a generous, full-throttle, high-octane...
# 36166       US  Flowery and balanced in crisp, dry flavors of ...
# 36167    Italy  Here's a straightforward and fruity Nero d'Avo...
# 36168   Greece  This rounded white starts with aromas of lemon...
#
#                designation  points  price           province  \
# 36164                  NaN      92   20.0          Eisenberg
# 36165  Epicenter Old Vines      88   20.0         California
# 36166             La Brume      88   32.0         California
# 36167                  NaN      88   18.0  Sicily & Sardinia
# 36168            Dry White      88   15.0        Peloponnese
#
#                region_1        region_2       taster_name  \
# 36164               NaN             NaN  Anne Krebiehl MW
# 36165              Lodi  Central Valley        Jim Gordon
# 36166  Dry Creek Valley          Sonoma    Virginie Boone
# 36167           Sicilia             NaN     Kerin O’Keefe
# 36168               NaN             NaN   Susan Kostrzewa
#
#       taster_twitter_handle  \
# 36164           @AnneInVino
# 36165      @gordone_cellars
# 36166               @vboone
# 36167          @kerinokeefe
# 36168         @suskostrzewa
#
#                                                    title        variety  \
# 36164              Jalits 2013 Blaufränkisch (Eisenberg)  Blaufränkisch
# 36165  Mettler Family Vineyards 2011 Epicenter Old Vi...      Zinfandel
# 36166  Michel-Schlumberger 2012 La Brume Chardonnay (...     Chardonnay
# 36167               Morgante 2012 Nero d'Avola (Sicilia)   Nero d'Avola
# 36168      My Big Fat Greek Wine 2012 Dry White Moschofi            NaN
#
#                          winery
# 36164                    Jalits
# 36165  Mettler Family Vineyards
# 36166       Michel-Schlumberger
# 36167                  Morgante
# 36168                       NaN

# %% [markdown]
# Label-based selection

# %%
# It's the data index value, not its position, which matters.
reviews.loc[0, 'country']
# Out:
# 'Italy'

# %%
""" iloc is conceptually simpler than loc because it ignores the dataset's indices.
When we use iloc we treat the dataset like a big matrix(a list of lists), one that we have to index into by position.
loc, by contrast, uses the information in the indices to do its work. 
Since your dataset usually has meaningful indices, it's usually easier to do things using loc instead."""

# %%
reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#            taster_name taster_twitter_handle  points
# 0        Kerin O’Keefe          @kerinokeefe      87
# 1           Roger Voss            @vossroger      87
# ...                ...                   ...     ...
# 36167    Kerin O’Keefe          @kerinokeefe      88
# 36168  Susan Kostrzewa         @suskostrzewa      88
#
# [36169 rows x 3 columns]

# %% [markdown]
# Choosing between loc and iloc

# %%
""" iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded.
loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,..., 10.

it's a lot more convenient to index df.loc['Apples':'Potatoes'] than it is to index something like df.loc['Apples', 'Potatoes']"""
# Out:
# ' iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded.\nloc, meanwhile, indexes inclusively. So 0:10 will select entries 0,..., 10.'

# %% [markdown]
# # Manipulating the index

# %%
reviews.set_index("title")
# Out:
#                                                 country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portugal
# ...                                                 ...
# Morgante 2012 Nero d'Avola (Sicilia)              Italy
# My Big Fat Greek Wine 2012 Dry White Moschofi    Greece
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
# ...                                                                                          ...
# Morgante 2012 Nero d'Avola (Sicilia)           Here's a straightforward and fruity Nero d'Avo...
# My Big Fat Greek Wine 2012 Dry White Moschofi  This rounded white starts with aromas of lemon...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
# ...                                                     ...     ...    ...
# Morgante 2012 Nero d'Avola (Sicilia)                    NaN      88   18.0
# My Big Fat Greek Wine 2012 Dry White Moschofi     Dry White      88   15.0
#
#                                                         province region_1  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Sicily & Sardinia     Etna
# Quinta dos Avidagos 2011 Avidagos Red (Douro)              Douro      NaN
# ...                                                          ...      ...
# Morgante 2012 Nero d'Avola (Sicilia)           Sicily & Sardinia  Sicilia
# My Big Fat Greek Wine 2012 Dry White Moschofi        Peloponnese      NaN
#
#                                               region_2      taster_name  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                  NaN    Kerin O’Keefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      NaN       Roger Voss
# ...                                                ...              ...
# Morgante 2012 Nero d'Avola (Sicilia)               NaN    Kerin O’Keefe
# My Big Fat Greek Wine 2012 Dry White Moschofi      NaN  Susan Kostrzewa
#
#                                               taster_twitter_handle  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      @kerinokeefe
# Quinta dos Avidagos 2011 Avidagos Red (Douro)            @vossroger
# ...                                                             ...
# Morgante 2012 Nero d'Avola (Sicilia)                   @kerinokeefe
# My Big Fat Greek Wine 2012 Dry White Moschofi         @suskostrzewa
#
#                                                       variety  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                 White Blend
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                                       ...
# Morgante 2012 Nero d'Avola (Sicilia)             Nero d'Avola
# My Big Fat Greek Wine 2012 Dry White Moschofi             NaN
#
#                                                             winery
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                          Nicosia
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  Quinta dos Avidagos
# ...                                                            ...
# Morgante 2012 Nero d'Avola (Sicilia)                      Morgante
# My Big Fat Greek Wine 2012 Dry White Moschofi                  NaN
#
# [36169 rows x 12 columns]

# %% [markdown]
# # Conditional selection

# %%
# For example, suppose that we're interested specifically in better-than-average wines produced in Italy.
# We can start by checking if each wine is Italian or not:
reviews.country == 'Italy'
# Out:
# 0         True
# 1        False
#          ...
# 36167     True
# 36168    False
# Name: country, Length: 36169, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 6       Italy  Here's a bright, informal red that opens with ...
# ...       ...                                                ...
# 36163   Italy  A blend of Petit Verdot and Cabernet Franc, th...
# 36167   Italy  Here's a straightforward and fruity Nero d'Avo...
#
#         designation  points  price           province  region_1 region_2  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 6           Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# ...             ...     ...    ...                ...       ...      ...
# 36163           NaN      92  170.0            Tuscany   Toscana      NaN
# 36167           NaN      88   18.0  Sicily & Sardinia   Sicilia      NaN
#
#          taster_name taster_twitter_handle  \
# 0      Kerin O’Keefe          @kerinokeefe
# 6      Kerin O’Keefe          @kerinokeefe
# ...              ...                   ...
# 36163  Kerin O’Keefe          @kerinokeefe
# 36167  Kerin O’Keefe          @kerinokeefe
#
#                                                   title       variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)   White Blend
# 6      Terre di Giurfo 2013 Belsito Frappato (Vittoria)      Frappato
# ...                                                 ...           ...
# 36163             Campo alla Sughera 2008 Red (Toscana)     Red Blend
# 36167              Morgante 2012 Nero d'Avola (Sicilia)  Nero d'Avola
#
#                    winery
# 0                 Nicosia
# 6         Terre di Giurfo
# ...                   ...
# 36163  Campo alla Sughera
# 36167            Morgante
#
# [5531 rows x 13 columns]

# %%
# made in Italy and also which is rated above average
reviews.loc[(reviews.country == 'Italy') & (reviews.points >= 90)]
# Out:
#       country                                        description  \
# 120     Italy  Slightly backward, particularly given the vint...
# 130     Italy  At the first it was quite muted and subdued, b...
# ...       ...                                                ...
# 36151   Italy  Violet, iris, leather, tobacco, vanilla and sa...
# 36163   Italy  A blend of Petit Verdot and Cabernet Franc, th...
#
#                  designation  points  price  province          region_1  \
# 120      Bricco Rocche Prapó      92   70.0  Piedmont            Barolo
# 130    Bricco Rocche Brunate      91   70.0  Piedmont            Barolo
# ...                      ...     ...    ...       ...               ...
# 36151         Gran Selezione      92  100.0   Tuscany  Chianti Classico
# 36163                    NaN      92  170.0   Tuscany           Toscana
#
#       region_2    taster_name taster_twitter_handle  \
# 120        NaN            NaN                   NaN
# 130        NaN            NaN                   NaN
# ...        ...            ...                   ...
# 36151      NaN  Kerin O’Keefe          @kerinokeefe
# 36163      NaN  Kerin O’Keefe          @kerinokeefe
#
#                                                    title     variety  \
# 120           Ceretto 2003 Bricco Rocche Prapó  (Barolo)    Nebbiolo
# 130         Ceretto 2003 Bricco Rocche Brunate  (Barolo)    Nebbiolo
# ...                                                  ...         ...
# 36151  Castello di Radda 2010 Gran Selezione  (Chiant...  Sangiovese
# 36163              Campo alla Sughera 2008 Red (Toscana)   Red Blend
#
#                    winery
# 120               Ceretto
# 130               Ceretto
# ...                   ...
# 36151   Castello di Radda
# 36163  Campo alla Sughera
#
# [1825 rows x 13 columns]

# %%
# made in Italy or which is rated above average
reviews.loc[(reviews.country == 'Italy') | (reviews.points >= 90)]
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# ...        ...                                                ...
# 36164  Austria  Distant woodsmoke, ripe blueberry and notions ...
# 36167    Italy  Here's a straightforward and fruity Nero d'Avo...
#
#         designation  points  price           province  region_1 region_2  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 6           Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# ...             ...     ...    ...                ...       ...      ...
# 36164           NaN      92   20.0          Eisenberg       NaN      NaN
# 36167           NaN      88   18.0  Sicily & Sardinia   Sicilia      NaN
#
#             taster_name taster_twitter_handle  \
# 0         Kerin O’Keefe          @kerinokeefe
# 6         Kerin O’Keefe          @kerinokeefe
# ...                 ...                   ...
# 36164  Anne Krebiehl MW           @AnneInVino
# 36167     Kerin O’Keefe          @kerinokeefe
#
#                                                   title        variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)    White Blend
# 6      Terre di Giurfo 2013 Belsito Frappato (Vittoria)       Frappato
# ...                                                 ...            ...
# 36164             Jalits 2013 Blaufränkisch (Eisenberg)  Blaufränkisch
# 36167              Morgante 2012 Nero d'Avola (Sicilia)   Nero d'Avola
#
#                 winery
# 0              Nicosia
# 6      Terre di Giurfo
# ...                ...
# 36164           Jalits
# 36167         Morgante
#
# [17270 rows x 13 columns]

# %%
# pandas built-in conditional selctors; isin
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 6       Italy  Here's a bright, informal red that opens with ...
# ...       ...                                                ...
# 36163   Italy  A blend of Petit Verdot and Cabernet Franc, th...
# 36167   Italy  Here's a straightforward and fruity Nero d'Avo...
#
#         designation  points  price           province  region_1 region_2  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia      Etna      NaN
# 6           Belsito      87   16.0  Sicily & Sardinia  Vittoria      NaN
# ...             ...     ...    ...                ...       ...      ...
# 36163           NaN      92  170.0            Tuscany   Toscana      NaN
# 36167           NaN      88   18.0  Sicily & Sardinia   Sicilia      NaN
#
#          taster_name taster_twitter_handle  \
# 0      Kerin O’Keefe          @kerinokeefe
# 6      Kerin O’Keefe          @kerinokeefe
# ...              ...                   ...
# 36163  Kerin O’Keefe          @kerinokeefe
# 36167  Kerin O’Keefe          @kerinokeefe
#
#                                                   title       variety  \
# 0                     Nicosia 2013 Vulkà Bianco  (Etna)   White Blend
# 6      Terre di Giurfo 2013 Belsito Frappato (Vittoria)      Frappato
# ...                                                 ...           ...
# 36163             Campo alla Sughera 2008 Red (Toscana)     Red Blend
# 36167              Morgante 2012 Nero d'Avola (Sicilia)  Nero d'Avola
#
#                    winery
# 0                 Nicosia
# 6         Terre di Giurfo
# ...                   ...
# 36163  Campo alla Sughera
# 36167            Morgante
#
# [11608 rows x 13 columns]

# %%
# pandas built-in conditional selctors; isnull(and its companion notnull)
# filter out wines lacking a price tag in the dataset
reviews.loc[reviews.price.notnull()]
# Out:
#         country                                        description  \
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# ...         ...                                                ...
# 36167     Italy  Here's a straightforward and fruity Nero d'Avo...
# 36168    Greece  This rounded white starts with aromas of lemon...
#
#       designation  points  price           province           region_1  \
# 1        Avidagos      87   15.0              Douro                NaN
# 2             NaN      87   14.0             Oregon  Willamette Valley
# ...           ...     ...    ...                ...                ...
# 36167         NaN      88   18.0  Sicily & Sardinia            Sicilia
# 36168   Dry White      88   15.0        Peloponnese                NaN
#
#                 region_2      taster_name taster_twitter_handle  \
# 1                    NaN       Roger Voss            @vossroger
# 2      Willamette Valley     Paul Gregutt           @paulgwine
# ...                  ...              ...                   ...
# 36167                NaN    Kerin O’Keefe          @kerinokeefe
# 36168                NaN  Susan Kostrzewa         @suskostrzewa
#
#                                                title         variety  \
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# ...                                              ...             ...
# 36167           Morgante 2012 Nero d'Avola (Sicilia)    Nero d'Avola
# 36168  My Big Fat Greek Wine 2012 Dry White Moschofi             NaN
#
#                     winery
# 1      Quinta dos Avidagos
# 2                Rainstorm
# ...                    ...
# 36167             Morgante
# 36168                  NaN
#
# [33541 rows x 13 columns]

# %% [markdown]
# # Assigning data

# %%
# Assign a constant value
reviews['critic'] = 'everyone'
reviews['critic']
# Out:
# 0        everyone
# 1        everyone
#            ...
# 36167    everyone
# 36168    everyone
# Name: critic, Length: 36169, dtype: object

# %%
# Or with an iterable of values
reviews['index_backwards'] = range(len(reviews), 0, -1)
reviews['index_backwards']
# Out:
# 0        36169
# 1        36168
#          ...
# 36167        2
# 36168        1
# Name: index_backwards, Length: 36169, dtype: int64
