# %%
import pandas as pd
pd.set_option('max_rows', 5)
import numpy as np
reviews = pd.read_csv('winemag-data-130k-v2.csv', index_col = 0)

# %%
reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 36167     Italy  Here's a straightforward and fruity Nero d'Avo...
# 36168    Greece  This rounded white starts with aromas of lemon...
#
#         designation  points  price           province region_1 region_2  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna      NaN
# 1          Avidagos      87   15.0              Douro      NaN      NaN
# ...             ...     ...    ...                ...      ...      ...
# 36167           NaN      88   18.0  Sicily & Sardinia  Sicilia      NaN
# 36168     Dry White      88   15.0        Peloponnese      NaN      NaN
#
#            taster_name taster_twitter_handle  \
# 0        Kerin O’Keefe          @kerinokeefe
# 1           Roger Voss            @vossroger
# ...                ...                   ...
# 36167    Kerin O’Keefe          @kerinokeefe
# 36168  Susan Kostrzewa         @suskostrzewa
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                              ...             ...
# 36167           Morgante 2012 Nero d'Avola (Sicilia)    Nero d'Avola
# 36168  My Big Fat Greek Wine 2012 Dry White Moschofi             NaN
#
#                     winery
# 0                  Nicosia
# 1      Quinta dos Avidagos
# ...                    ...
# 36167             Morgante
# 36168                  NaN
#
# [36169 rows x 13 columns]

# %% [markdown]
# # Summary functions

# %%
reviews.points.describe()   # 데이터타입: float64
# Out:
# count    36169.000000
# mean        88.397274
#              ...
# 75%         91.000000
# max        100.000000
# Name: points, Length: 8, dtype: float64

# %%
reviews.taster_name.describe()    # 데이터타입: object
# Out:
# count          28743
# unique            19
# top       Roger Voss
# freq            7175
# Name: taster_name, dtype: object

# %%
reviews.points.mean()    # points열의 평균
# Out:
# 88.39727390859576

# %%
reviews.taster_name.unique()    # taster_name열의 고유값 전체
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
reviews.taster_name.value_counts()    # taster_name열의 각 고유값의 개수
# Out:
# Roger Voss           7175
# Michael Schachner    4360
#                      ...
# Fiona Adams            11
# Christina Pickard       1
# Name: taster_name, Length: 19, dtype: int64

# %% [markdown]
# # Maps

# %%
# map() returns a new Series where all the values have been transformed by your function
review_points_mean = reviews.points.mean()
reviews.points.map(lambda p: p - review_points_mean)    # map()는 Series중에서 단 하나의 값만을 취함
# Out:
# 0       -1.397274
# 1       -1.397274
#            ...
# 36167   -0.397274
# 36168   -0.397274
# Name: points, Length: 36169, dtype: float64

# %%
# apply() is the equivalent method if we want to transform a whole DataFrame
# by calling a custom method on each row.
def remean_points(row):
    row.points = row.points - review_points_mean
    return row

reviews.apply(remean_points, axis = 'columns')
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 36167     Italy  Here's a straightforward and fruity Nero d'Avo...
# 36168    Greece  This rounded white starts with aromas of lemon...
#
#         designation    points  price           province region_1 region_2  \
# 0      Vulkà Bianco -1.397274    NaN  Sicily & Sardinia     Etna      NaN
# 1          Avidagos -1.397274   15.0              Douro      NaN      NaN
# ...             ...       ...    ...                ...      ...      ...
# 36167           NaN -0.397274   18.0  Sicily & Sardinia  Sicilia      NaN
# 36168     Dry White -0.397274   15.0        Peloponnese      NaN      NaN
#
#            taster_name taster_twitter_handle  \
# 0        Kerin O’Keefe          @kerinokeefe
# 1           Roger Voss            @vossroger
# ...                ...                   ...
# 36167    Kerin O’Keefe          @kerinokeefe
# 36168  Susan Kostrzewa         @suskostrzewa
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ...                                              ...             ...
# 36167           Morgante 2012 Nero d'Avola (Sicilia)    Nero d'Avola
# 36168  My Big Fat Greek Wine 2012 Dry White Moschofi             NaN
#
#                     winery
# 0                  Nicosia
# 1      Quinta dos Avidagos
# ...                    ...
# 36167             Morgante
# 36168                  NaN
#
# [36169 rows x 13 columns]

# %%
# map() and apply() return new, transformed Series and DataFrames
# They don't modify the original data
reviews.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %%
# Pandas figures out that we must subtract mean value from every value in the dataset
review_points_mean = reviews.points.mean()
reviews.points - review_points_mean
# Out:
# 0       -1.397274
# 1       -1.397274
#            ...
# 36167   -0.397274
# 36168   -0.397274
# Name: points, Length: 36169, dtype: float64

# %%
# Pandas understand what to do if we perform these operations between Series of equal length
# Combining country and region
reviews.country + ' - ' + reviews.region_1
# Out:
# 0           Italy - Etna
# 1                    NaN
#               ...
# 36167    Italy - Sicilia
# 36168                NaN
# Length: 36169, dtype: object
